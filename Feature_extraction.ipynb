# %%
import pandas as pd
from yaml import safe_load
import numpy as np
import os
from tqdm import tqdm

# %%
final_df = pd.read_csv("/content/t20i_info.csv")

final_df.shape


final_df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed     city                     venue
# 0                    0      NaN  Melbourne Cricket Ground
# 1                    0      NaN  Melbourne Cricket Ground
# 2                    0      NaN  Melbourne Cricket Ground
# 3                    0      NaN  Melbourne Cricket Ground
# 4                    0      NaN  Melbourne Cricket Ground
# ...                ...      ...                       ...
# 63883                0  Colombo       R Premadasa Stadium
# 63884                0  Colombo       R Premadasa Stadium
# 63885      DM de Silva  Colombo       R Premadasa Stadium
# 63886                0  Colombo       R Premadasa Stadium
# 63887                0  Colombo       R Premadasa Stadium
#
# [63888 rows x 9 columns]

# %%
final_df.isnull().sum()
# Out:
# Unnamed: 0             0
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
cities=np.where(final_df['city'].isnull(),final_df['venue'].str.split().apply(lambda x:x[0]),final_df['city'])

# %%
final_df['city']=cities

# %%
final_df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
final_df.drop(columns='venue',inplace=True)

# %%
final_df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city
# 0                    0  Melbourne
# 1                    0  Melbourne
# 2                    0  Melbourne
# 3                    0  Melbourne
# 4                    0  Melbourne
# ...                ...        ...
# 63883                0    Colombo
# 63884                0    Colombo
# 63885      DM de Silva    Colombo
# 63886                0    Colombo
# 63887                0    Colombo
#
# [63888 rows x 8 columns]

# %%
final_df['city'].value_counts()
# Out:
# city
# Colombo          4086
# Mirpur           3420
# Johannesburg     3331
# Dubai            2969
# Auckland         2532
#                  ...
# Victoria          123
# Potchefstroom     122
# Dharamsala        122
# Ahmedabad         121
# Carrara            64
# Name: count, Length: 86, dtype: int64

# %%
final_df['city'].value_counts()[final_df['city'].value_counts()>600].shape
# Out:
# (35,)

# %%
final_df['city'].value_counts()[final_df['city'].value_counts()>600].sum()
# Out:
# np.int64(50501)

# %%
eligible=final_df['city'].value_counts()[final_df['city'].value_counts()>600].index.tolist()

# %%
df = final_df[final_df['city'].isin(eligible)].copy()

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city
# 0                    0  Melbourne
# 1                    0  Melbourne
# 2                    0  Melbourne
# 3                    0  Melbourne
# 4                    0  Melbourne
# ...                ...        ...
# 63883                0    Colombo
# 63884                0    Colombo
# 63885      DM de Silva    Colombo
# 63886                0    Colombo
# 63887                0    Colombo
#
# [50501 rows x 8 columns]

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
df['curr_score']=df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city  curr_score
# 0                    0  Melbourne           0
# 1                    0  Melbourne           0
# 2                    0  Melbourne           1
# 3                    0  Melbourne           3
# 4                    0  Melbourne           3
# ...                ...        ...         ...
# 63883                0    Colombo         125
# 63884                0    Colombo         125
# 63885      DM de Silva    Colombo         125
# 63886                0    Colombo         127
# 63887                0    Colombo         128
#
# [50501 rows x 9 columns]

# %%
df['over']=df['ball'].apply(lambda x:str(x).split(".")[0])
df['balls']=df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city  curr_score over balls
# 0                    0  Melbourne           0    0     1
# 1                    0  Melbourne           0    0     2
# 2                    0  Melbourne           1    0     3
# 3                    0  Melbourne           3    0     4
# 4                    0  Melbourne           3    0     5
# ...                ...        ...         ...  ...   ...
# 63883                0    Colombo         125   19     3
# 63884                0    Colombo         125   19     4
# 63885      DM de Silva    Colombo         125   19     5
# 63886                0    Colombo         127   19     6
# 63887                0    Colombo         128   19     7
#
# [50501 rows x 11 columns]

# %%
df['balls_bowled']=(df['over'].astype('int')*6+df['balls'].astype('int'))

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city  curr_score over balls  balls_bowled
# 0                    0  Melbourne           0    0     1             1
# 1                    0  Melbourne           0    0     2             2
# 2                    0  Melbourne           1    0     3             3
# 3                    0  Melbourne           3    0     4             4
# 4                    0  Melbourne           3    0     5             5
# ...                ...        ...         ...  ...   ...           ...
# 63883                0    Colombo         125   19     3           117
# 63884                0    Colombo         125   19     4           118
# 63885      DM de Silva    Colombo         125   19     5           119
# 63886                0    Colombo         127   19     6           120
# 63887                0    Colombo         128   19     7           121
#
# [50501 rows x 12 columns]

# %%
df['balls_left']=120-df['balls_bowled']
df['balls_left']=df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city  curr_score over balls  balls_bowled  \
# 0                    0  Melbourne           0    0     1             1
# 1                    0  Melbourne           0    0     2             2
# 2                    0  Melbourne           1    0     3             3
# 3                    0  Melbourne           3    0     4             4
# 4                    0  Melbourne           3    0     5             5
# ...                ...        ...         ...  ...   ...           ...
# 63883                0    Colombo         125   19     3           117
# 63884                0    Colombo         125   19     4           118
# 63885      DM de Silva    Colombo         125   19     5           119
# 63886                0    Colombo         127   19     6           120
# 63887                0    Colombo         128   19     7           121
#
#        balls_left
# 0             119
# 1             118
# 2             117
# 3             116
# 4             115
# ...           ...
# 63883           3
# 63884           2
# 63885           1
# 63886           0
# 63887           0
#
# [50501 rows x 13 columns]

# %%
df['players_dismissed']=df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['players_dismissed']=df['players_dismissed'].astype('int')
df['players_dismissed']=df.groupby('match_id')['players_dismissed'].cumsum()
df['wickets_left']=10-df['players_dismissed']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city  curr_score over balls  balls_bowled  \
# 0                    0  Melbourne           0    0     1             1
# 1                    0  Melbourne           0    0     2             2
# 2                    0  Melbourne           1    0     3             3
# 3                    0  Melbourne           3    0     4             4
# 4                    0  Melbourne           3    0     5             5
# ...                ...        ...         ...  ...   ...           ...
# 63883                0    Colombo         125   19     3           117
# 63884                0    Colombo         125   19     4           118
# 63885      DM de Silva    Colombo         125   19     5           119
# 63886                0    Colombo         127   19     6           120
# 63887                0    Colombo         128   19     7           121
#
#        balls_left  players_dismissed  wickets_left
# 0             119                  0            10
# 1             118                  0            10
# 2             117                  0            10
# 3             116                  0            10
# 4             115                  0            10
# ...           ...                ...           ...
# 63883           3                  8             2
# 63884           2                  8             2
# 63885           1                  9             1
# 63886           0                  9             1
# 63887           0                  9             1
#
# [50501 rows x 15 columns]

# %%
df['crr']=(df['curr_score']*6)/df['balls_bowled']

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city  curr_score over balls  balls_bowled  \
# 0                    0  Melbourne           0    0     1             1
# 1                    0  Melbourne           0    0     2             2
# 2                    0  Melbourne           1    0     3             3
# 3                    0  Melbourne           3    0     4             4
# 4                    0  Melbourne           3    0     5             5
# ...                ...        ...         ...  ...   ...           ...
# 63883                0    Colombo         125   19     3           117
# 63884                0    Colombo         125   19     4           118
# 63885      DM de Silva    Colombo         125   19     5           119
# 63886                0    Colombo         127   19     6           120
# 63887                0    Colombo         128   19     7           121
#
#        balls_left  players_dismissed  wickets_left       crr
# 0             119                  0            10  0.000000
# 1             118                  0            10  0.000000
# 2             117                  0            10  2.000000
# 3             116                  0            10  4.500000
# 4             115                  0            10  3.600000
# ...           ...                ...           ...       ...
# 63883           3                  8             2  6.410256
# 63884           2                  8             2  6.355932
# 63885           1                  9             1  6.302521
# 63886           0                  9             1  6.350000
# 63887           0                  9             1  6.347107
#
# [50501 rows x 16 columns]

# %%
from pandas.tseries.offsets import LastWeekOfMonth
groups=df.groupby('match_id')
match_ids=df['match_id'].unique()
last_five=[]
for id in match_ids:
  last_five.extend(groups.get_group(id)['runs'].rolling(window=30).sum().values.tolist())

# %%
last_five
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  43.0,
#  44.0,
#  45.0,
#  44.0,
#  42.0,
#  43.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  42.0,
#  39.0,
#  38.0,
#  39.0,
#  38.0,
#  39.0,
#  40.0,
#  37.0,
#  41.0,
#  42.0,
#  42.0,
#  44.0,
#  44.0,
#  40.0,
#  39.0,
#  37.0,
#  35.0,
#  31.0,
#  27.0,
#  26.0,
#  31.0,
#  31.0,
#  30.0,
#  31.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  32.0,
#  32.0,
#  31.0,
#  29.0,
#  29.0,
#  31.0,
#  32.0,
#  32.0,
#  32.0,
#  33.0,
#  36.0,
#  37.0,
#  37.0,
#  39.0,
#  41.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  44.0,
#  39.0,
#  43.0,
#  45.0,
#  48.0,
#  48.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  51.0,
#  51.0,
#  51.0,
#  52.0,
#  52.0,
#  53.0,
#  53.0,
#  53.0,
#  54.0,
#  53.0,
#  52.0,
#  50.0,
#  53.0,
#  47.0,
#  46.0,
#  45.0,
#  46.0,
#  47.0,
#  49.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  46.0,
#  52.0,
#  53.0,
#  57.0,
#  58.0,
#  59.0,
#  59.0,
#  59.0,
#  53.0,
#  53.0,
#  54.0,
#  50.0,
#  50.0,
#  49.0,
#  50.0,
#  47.0,
#  48.0,
#  49.0,
#  49.0,
#  46.0,
#  46.0,
#  51.0,
#  48.0,
#  48.0,
#  48.0,
#  44.0,
#  45.0,
#  42.0,
#  43.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  36.0,
#  35.0,
#  39.0,
#  39.0,
#  38.0,
#  38.0,
#  37.0,
#  37.0,
#  38.0,
#  39.0,
#  41.0,
#  40.0,
#  40.0,
#  39.0,
#  38.0,
#  39.0,
#  42.0,
#  47.0,
#  42.0,
#  45.0,
#  45.0,
#  49.0,
#  49.0,
#  48.0,
#  47.0,
#  45.0,
#  45.0,
#  45.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  37.0,
#  38.0,
#  39.0,
#  43.0,
#  46.0,
#  47.0,
#  47.0,
#  46.0,
#  50.0,
#  56.0,
#  57.0,
#  60.0,
#  59.0,
#  59.0,
#  55.0,
#  51.0,
#  51.0,
#  51.0,
#  53.0,
#  51.0,
#  51.0,
#  52.0,
#  53.0,
#  54.0,
#  53.0,
#  54.0,
#  53.0,
#  52.0,
#  51.0,
#  51.0,
#  51.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  42.0,
#  42.0,
#  43.0,
#  42.0,
#  42.0,
#  43.0,
#  40.0,
#  40.0,
#  37.0,
#  33.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  36.0,
#  37.0,
#  34.0,
#  39.0,
#  35.0,
#  36.0,
#  36.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  34.0,
#  35.0,
#  41.0,
#  43.0,
#  41.0,
#  42.0,
#  43.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  47.0,
#  50.0,
#  51.0,
#  52.0,
#  57.0,
#  53.0,
#  58.0,
#  61.0,
#  59.0,
#  65.0,
#  68.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  74.0,
#  73.0,
#  68.0,
#  67.0,
#  66.0,
#  66.0,
#  66.0,
#  70.0,
#  70.0,
#  71.0,
#  71.0,
#  72.0,
#  74.0,
#  69.0,
#  65.0,
#  66.0,
#  64.0,
#  59.0,
#  58.0,
#  53.0,
#  50.0,
#  48.0,
#  43.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  38.0,
#  41.0,
#  42.0,
#  40.0,
#  40.0,
#  41.0,
#  40.0,
#  41.0,
#  40.0,
#  40.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  36.0,
#  36.0,
#  35.0,
#  35.0,
#  32.0,
#  32.0,
#  32.0,
#  31.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  27.0,
#  27.0,
#  27.0,
#  26.0,
#  27.0,
#  28.0,
#  25.0,
#  21.0,
#  20.0,
#  17.0,
#  18.0,
#  18.0,
#  18.0,
#  18.0,
#  19.0,
#  19.0,
#  19.0,
#  20.0,
#  21.0,
#  25.0,
#  26.0,
#  27.0,
#  28.0,
#  34.0,
#  34.0,
#  34.0,
#  35.0,
#  38.0,
#  40.0,
#  44.0,
#  45.0,
#  45.0,
#  45.0,
#  46.0,
#  51.0,
#  54.0,
#  53.0,
#  53.0,
#  53.0,
#  56.0,
#  56.0,
#  59.0,
#  64.0,
#  70.0,
#  70.0,
#  71.0,
#  69.0,
#  67.0,
#  67.0,
#  63.0,
#  62.0,
#  62.0,
#  67.0,
#  67.0,
#  72.0,
#  73.0,
#  71.0,
#  68.0,
#  68.0,
#  65.0,
#  68.0,
#  68.0,
#  74.0,
#  73.0,
#  69.0,
#  66.0,
#  68.0,
#  74.0,
#  74.0,
#  71.0,
#  76.0,
#  73.0,
#  68.0,
#  62.0,
#  67.0,
#  68.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  41.0,
#  42.0,
#  39.0,
#  43.0,
#  44.0,
#  47.0,
#  51.0,
#  51.0,
#  48.0,
#  44.0,
#  44.0,
#  45.0,
#  46.0,
#  47.0,
#  49.0,
#  49.0,
#  50.0,
#  52.0,
#  54.0,
#  54.0,
#  54.0,
#  55.0,
#  54.0,
#  60.0,
#  61.0,
#  56.0,
#  58.0,
#  58.0,
#  54.0,
#  56.0,
#  57.0,
#  56.0,
#  55.0,
#  52.0,
#  51.0,
#  48.0,
#  45.0,
#  46.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  44.0,
#  43.0,
#  43.0,
#  45.0,
#  44.0,
#  47.0,
#  47.0,
#  46.0,
#  49.0,
#  44.0,
#  43.0,
#  46.0,
#  40.0,
#  38.0,
#  44.0,
#  39.0,
#  39.0,
#  40.0,
#  41.0,
#  40.0,
#  46.0,
#  45.0,
#  45.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  47.0,
#  50.0,
#  50.0,
#  50.0,
#  55.0,
#  52.0,
#  51.0,
#  53.0,
#  53.0,
#  53.0,
#  50.0,
#  49.0,
#  50.0,
#  46.0,
#  46.0,
#  50.0,
#  44.0,
#  43.0,
#  44.0,
#  43.0,
#  46.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  33.0,
#  33.0,
#  36.0,
#  36.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  36.0,
#  36.0,
#  32.0,
#  33.0,
#  32.0,
#  29.0,
#  23.0,
#  23.0,
#  26.0,
#  27.0,
#  27.0,
#  27.0,
#  27.0,
#  26.0,
#  27.0,
#  27.0,
#  27.0,
#  23.0,
#  24.0,
#  25.0,
#  27.0,
#  27.0,
#  28.0,
#  29.0,
#  26.0,
#  27.0,
#  26.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  26.0,
#  27.0,
#  27.0,
#  26.0,
#  28.0,
#  28.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  24.0,
#  25.0,
#  24.0,
#  25.0,
#  25.0,
#  29.0,
#  30.0,
#  29.0,
#  31.0,
#  31.0,
#  31.0,
#  31.0,
#  30.0,
#  29.0,
#  30.0,
#  29.0,
#  34.0,
#  34.0,
#  35.0,
#  35.0,
#  34.0,
#  33.0,
#  38.0,
#  39.0,
#  37.0,
#  38.0,
#  38.0,
#  38.0,
#  37.0,
#  38.0,
#  40.0,
#  43.0,
#  49.0,
#  50.0,
#  51.0,
#  47.0,
#  46.0,
#  52.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  38.0,
#  39.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  38.0,
#  42.0,
#  43.0,
#  39.0,
#  38.0,
#  35.0,
#  36.0,
#  36.0,
#  40.0,
#  35.0,
#  38.0,
#  38.0,
#  42.0,
#  41.0,
#  42.0,
#  41.0,
#  41.0,
#  41.0,
#  46.0,
#  43.0,
#  42.0,
#  41.0,
#  43.0,
#  43.0,
#  42.0,
#  41.0,
#  44.0,
#  47.0,
#  48.0,
#  49.0,
#  52.0,
#  49.0,
#  48.0,
#  52.0,
#  53.0,
#  53.0,
#  58.0,
#  58.0,
#  58.0,
#  61.0,
#  58.0,
#  59.0,
#  55.0,
#  57.0,
#  57.0,
#  57.0,
#  61.0,
#  61.0,
#  55.0,
#  58.0,
#  59.0,
#  61.0,
#  56.0,
#  56.0,
#  57.0,
#  58.0,
#  54.0,
#  51.0,
#  54.0,
#  53.0,
#  51.0,
#  52.0,
#  53.0,
#  50.0,
#  49.0,
#  48.0,
#  43.0,
#  48.0,
#  48.0,
#  44.0,
#  43.0,
#  48.0,
#  48.0,
#  45.0,
#  44.0,
#  43.0,
#  41.0,
#  43.0,
#  45.0,
#  47.0,
#  47.0,
#  45.0,
#  45.0,
#  44.0,
#  43.0,
#  42.0,
#  42.0,
#  42.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  37.0,
#  40.0,
#  40.0,
#  41.0,
#  42.0,
#  39.0,
#  39.0,
#  42.0,
#  43.0,
#  44.0,
#  44.0,
#  44.0,
#  42.0,
#  41.0,
#  41.0,
#  41.0,
#  35.0,
#  31.0,
#  30.0,
#  29.0,
#  27.0,
#  27.0,
#  23.0,
#  23.0,
#  24.0,
#  29.0,
#  29.0,
#  28.0,
#  28.0,
#  28.0,
#  29.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  30.0,
#  29.0,
#  29.0,
#  29.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  37.0,
#  41.0,
#  41.0,
#  42.0,
#  46.0,
#  47.0,
#  48.0,
#  47.0,
#  47.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  41.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  37.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  33.0,
#  33.0,
#  38.0,
#  36.0,
#  35.0,
#  34.0,
#  35.0,
#  36.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
df['last_five']=last_five

# %%
df
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0               0         2    Australia    Sri Lanka   0.1     0
# 1               1         2    Australia    Sri Lanka   0.2     0
# 2               2         2    Australia    Sri Lanka   0.3     1
# 3               3         2    Australia    Sri Lanka   0.4     2
# 4               4         2    Australia    Sri Lanka   0.5     0
# ...           ...       ...          ...          ...   ...   ...
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed       city  curr_score over balls  balls_bowled  \
# 0                    0  Melbourne           0    0     1             1
# 1                    0  Melbourne           0    0     2             2
# 2                    0  Melbourne           1    0     3             3
# 3                    0  Melbourne           3    0     4             4
# 4                    0  Melbourne           3    0     5             5
# ...                ...        ...         ...  ...   ...           ...
# 63883                0    Colombo         125   19     3           117
# 63884                0    Colombo         125   19     4           118
# 63885      DM de Silva    Colombo         125   19     5           119
# 63886                0    Colombo         127   19     6           120
# 63887                0    Colombo         128   19     7           121
#
#        balls_left  players_dismissed  wickets_left       crr  last_five
# 0             119                  0            10  0.000000        NaN
# 1             118                  0            10  0.000000        NaN
# 2             117                  0            10  2.000000        NaN
# 3             116                  0            10  4.500000        NaN
# 4             115                  0            10  3.600000        NaN
# ...           ...                ...           ...       ...        ...
# 63883           3                  8             2  6.410256       32.0
# 63884           2                  8             2  6.355932       32.0
# 63885           1                  9             1  6.302521       32.0
# 63886           0                  9             1  6.350000       33.0
# 63887           0                  9             1  6.347107       32.0
#
# [50501 rows x 17 columns]

# %%
df=df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
df=df[['batting_team','bowling_team','city','curr_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
df.isnull().sum()
# Out:
# batting_team        0
# bowling_team        0
# city                0
# curr_score          0
# balls_left          0
# wickets_left        0
# crr                 0
# last_five       12024
# runs_x              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# curr_score      0
# balls_left      0
# wickets_left    0
# crr             0
# last_five       0
# runs_x          0
# dtype: int64

# %%
df=df.sample(df.shape[0])

# %%
df
# Out:
#       batting_team  bowling_team          city  curr_score  balls_left  \
# 21076  New Zealand      Pakistan        London          55          63
# 30929      England      Pakistan         Dubai          90          52
# 9136   West Indies         India       Kolkata          49          59
# 17649        India  South Africa        Durban         139           5
# 21726     Pakistan  South Africa    Nottingham         128          23
# ...            ...           ...           ...         ...         ...
# 19012    Australia       England    Manchester          69          53
# 25782        India     Sri Lanka      St Lucia         117          39
# 49917    Sri Lanka         India        Mirpur         138           0
# 15999  New Zealand     Sri Lanka  Johannesburg         118          30
# 35590     Pakistan  South Africa     Centurion         155          33
#
#        wickets_left        crr  last_five  runs_x
# 21076             6   5.789474       22.0      99
# 30929             6   7.941176       42.0     150
# 9136              5   4.819672       18.0     109
# 17649             6   7.252174       45.0     153
# 21726             6   7.917526       40.0     149
# ...             ...        ...        ...     ...
# 19012             7   6.179104       23.0     145
# 25782             8   8.666667       39.0     163
# 49917             1   6.900000       44.0     138
# 15999             5   7.866667       37.0     164
# 35590             8  10.689655       58.0     195
#
# [38477 rows x 9 columns]

# %%
X=df.drop(columns=['runs_x'])
y=df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf=ColumnTransformer(
    [('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])],remainder='passthrough'
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

categorical_features = ['batting_team', 'bowling_team', 'city']
numerical_features = ['curr_score', 'balls_left', 'wickets_left', 'crr', 'last_five']

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(sparse_output=False, drop='first'), categorical_features),
        ('num', StandardScaler(), numerical_features)
    ],
    remainder='passthrough'
)

rf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=100, random_state=1))
])

rf_pipeline.fit(X_train, y_train)
print("RandomForestRegressor pipeline created and trained successfully.")
# Out:
# RandomForestRegressor pipeline created and trained successfully.

# %%
y_pred_rf = rf_pipeline.predict(X_test)

r2_rf = r2_score(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)

print(f"RandomForestRegressor R-squared: {r2_rf:.4f}")
print(f"RandomForestRegressor Mean Absolute Error: {mae_rf:.4f}")
# Out:
# RandomForestRegressor R-squared: 0.9791
# RandomForestRegressor Mean Absolute Error: 2.0793

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor


xgb_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor(n_estimators=1000, random_state=1, learning_rate=0.2,max_depth=12))
])


xgb_pipeline.fit(X_train, y_train)
print("XGBRegressor pipeline created and trained successfully.")
# Out:
# XGBRegressor pipeline created and trained successfully.

# %%
y_pred_xgb = xgb_pipeline.predict(X_test)

r2_xgb = r2_score(y_test, y_pred_xgb)
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)

print(f"XGBRegressor R-squared: {r2_xgb:.4f}")
print(f"XGBRegressor Mean Absolute Error: {mae_xgb:.4f}")
# Out:
# XGBRegressor R-squared: 0.9887
# XGBRegressor Mean Absolute Error: 1.6102

# %%
print(f"\n--- Model Performance Comparison ---")
print(f"RandomForestRegressor R-squared: {r2_rf:.4f}")
print(f"RandomForestRegressor Mean Absolute Error: {mae_rf:.4f}")
print(f"XGBRegressor R-squared: {r2_xgb:.4f}")
print(f"XGBRegressor Mean Absolute Error: {mae_xgb:.4f}")

if r2_rf > r2_xgb and mae_rf < mae_xgb:
    print("\nBased on the R-squared and Mean Absolute Error, RandomForestRegressor performed better.")
elif r2_xgb > r2_rf and mae_xgb < mae_rf:
    print("\nBased on the R-squared and Mean Absolute Error, XGBRegressor performed better.")
else:
    print("\nThe performance of both models is comparable or requires further analysis to determine a clear winner.")
# Out:
# --- Model Performance Comparison ---
# RandomForestRegressor R-squared: 0.9791
# RandomForestRegressor Mean Absolute Error: 2.0793
# XGBRegressor R-squared: 0.9887
# XGBRegressor Mean Absolute Error: 1.6102
#
# Based on the R-squared and Mean Absolute Error, XGBRegressor performed better.

# %%
import pickle

with open("xgb_pipeline.pkl", "wb") as f:
    pickle.dump(xgb_pipeline, f)

# %%
unique_cities = df['city'].unique().tolist()
print(unique_cities)
# Out:
# ['London', 'Dubai', 'Kolkata', 'Durban', 'Nottingham', 'Mumbai', 'Manchester', 'Mirpur', 'Colombo', 'Mount Maunganui', 'Melbourne', 'Delhi', 'Johannesburg', 'Barbados', 'Nagpur', 'Auckland', 'Centurion', 'Chittagong', 'Sydney', 'Cape Town', 'Pallekele', 'St Lucia', 'Abu Dhabi', 'Wellington', 'Hamilton', 'Christchurch', 'Adelaide', 'Trinidad', 'Lauderhill', 'Chandigarh', 'St Kitts', 'Cardiff', 'Lahore', 'Bangalore', 'Southampton']
