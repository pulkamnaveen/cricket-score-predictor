# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []

base_path = "/content/drive/MyDrive/Ball to ball"

for file in os.listdir(base_path):
    if file.endswith(".yaml"):
        filenames.append(os.path.join(base_path, file))

len(filenames)
# Out:
# 4983

# %%
filenames[0:5]
# Out:
# ['/content/drive/MyDrive/Ball to ball/1321258.yaml',
#  '/content/drive/MyDrive/Ball to ball/1373569.yaml',
#  '/content/drive/MyDrive/Ball to ball/1486095.yaml',
#  '/content/drive/MyDrive/Ball to ball/1031431.yaml',
#  '/content/drive/MyDrive/Ball to ball/1311744.yaml']

# %%
if os.path.exists("final.csv"):
    os.remove("final.csv")

# %%
all_cols = set()

for file in tqdm(filenames):
    with open(file, "r") as f:
        df = pd.json_normalize(safe_load(f))
        all_cols.update(df.columns)

all_cols = list(all_cols)
len(all_cols)
# Out:
# 100%|██████████| 4983/4983 [13:19<00:00,  6.23it/s]
# 7872

# %%
processed_data_for_df = []
counter = 1

for file_path in tqdm(filenames):
    with open(file_path, "r") as f:
        raw_data = safe_load(f)

        info = raw_data.get('info', {})
        innings = raw_data.get('innings', [])
        temp_df = pd.json_normalize({"info": info}, sep='.')

        # Add match_id
        temp_df['match_id'] = counter

        # Assign the 'innings' list wrapped in another list to store it as a single object
        temp_df['innings'] = [innings]

        # Convert the 1-row DataFrame to a dictionary and append
        processed_data_for_df.append(temp_df.iloc[0].to_dict())

        counter += 1

# Create the final DataFrame from the processed data
final_df = pd.DataFrame(processed_data_for_df)

# Removed the df.to_csv("final.csv") part from here to prevent incorrect serialization
# The final_df will now retain its complex object types in memory for pickling.
# Out:
# 100%|██████████| 4983/4983 [14:00<00:00,  5.93it/s]

# %%
# This cell is no longer needed as final_df is generated directly in memory by 7SprWWsgjH_t
# and we do not want to overwrite it by reading from an potentially outdated final.csv.
# final_df = pd.read_csv("final.csv")

final_df.shape
final_df.head()
# Out:
#    info.balls_per_over    info.city    info.dates info.gender info.match_type  \
# 0                    6       Kerava  [2022-07-12]        male             T20
# 1                    6       Durban  [2023-09-01]        male             T20
# 2                    6         Rome  [2025-05-26]      female             T20
# 3                    6  Southampton  [2017-06-21]        male             T20
# 4                    6        Ajman  [2022-04-27]      female             T20
#
#    info.match_type_number   info.outcome.winner  info.outcome.by.wickets  \
# 0                  1639.0           Isle of Man                      8.0
# 1                  2228.0             Australia                      8.0
# 2                  2311.0                 Italy                     10.0
# 3                     NaN               England                      9.0
# 4                  1064.0  United Arab Emirates                      7.0
#
#    info.overs info.player_of_match  ... info.registry.people.Mohammed Aslam  \
# 0          20          [G Burrows]  ...                                 NaN
# 1          20          [SA Abbott]  ...                                 NaN
# 2          20      [D Nanayakkara]  ...                                 NaN
# 3          20        [JM Bairstow]  ...                                 NaN
# 4          20     [CR Seneviratna]  ...                                 NaN
#
#   info.registry.people.Mukhtiar Singh info.registry.people.Marija Mratinkovic  \
# 0                                 NaN                                     NaN
# 1                                 NaN                                     NaN
# 2                                 NaN                                     NaN
# 3                                 NaN                                     NaN
# 4                                 NaN                                     NaN
#
#   info.registry.people.Adnan Mufti info.registry.people.D Bau  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
#
#   info.registry.people.L Sreekumar info.registry.people.Mubeen Tariq  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#   info.registry.people.F Pieters info.registry.people.Aarsheya Sharma  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#   info.registry.people.S Vaidyanathan
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 7870 columns]

# %%
required_cols = [
    "innings",
    "info.dates",
    "info.gender",
    "info.match_type",
    "info.outcome.winner",
    "info.overs",
    "info.player_of_match",
    "info.teams",
    "info.toss.decision",
    "info.toss.winner",
    "info.umpires",
    "info.venue",
    "match_id",
    "info.city"
]

final_df = final_df.loc[:, required_cols]

# %%
final_df
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Cyprus', 'deliverie...  [2022-07-12]
# 1     [{'1st innings': {'team': 'South Africa', 'del...  [2023-09-01]
# 2     [{'1st innings': {'team': 'Sweden', 'deliverie...  [2025-05-26]
# 3     [{'1st innings': {'team': 'South Africa', 'del...  [2017-06-21]
# 4     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2022-04-27]
# ...                                                 ...           ...
# 4978  [{'1st innings': {'team': 'Indonesia', 'delive...  [2025-07-10]
# 4979  [{'1st innings': {'team': 'Philippines', 'deli...  [2024-10-05]
# 4980  [{'1st innings': {'team': 'England', 'deliveri...  [2024-06-15]
# 4981  [{'1st innings': {'team': 'Singapore', 'delive...  [2024-12-27]
# 4982  [{'1st innings': {'team': 'Thailand', 'deliver...  [2025-05-06]
#
#      info.gender info.match_type   info.outcome.winner  info.overs  \
# 0           male             T20           Isle of Man          20
# 1           male             T20             Australia          20
# 2         female             T20                 Italy          20
# 3           male             T20               England          20
# 4         female             T20  United Arab Emirates          20
# ...          ...             ...                   ...         ...
# 4978        male             T20           Philippines          20
# 4979        male             T20           Philippines          20
# 4980        male             T20               England          20
# 4981      female             T20           Philippines          20
# 4982      female             T20              Thailand          20
#
#      info.player_of_match                         info.teams  \
# 0             [G Burrows]              [Cyprus, Isle of Man]
# 1             [SA Abbott]          [South Africa, Australia]
# 2         [D Nanayakkara]                    [Sweden, Italy]
# 3           [JM Bairstow]            [England, South Africa]
# 4        [CR Seneviratna]  [Hong Kong, United Arab Emirates]
# ...                   ...                                ...
# 4978          [KD Kesuma]           [Indonesia, Philippines]
# 4979         [KDA Lukies]         [Philippines, South Korea]
# 4980           [HC Brook]                 [England, Namibia]
# 4981          [AR Valdez]           [Singapore, Philippines]
# 4982            [S Laomi]   [Thailand, United Arab Emirates]
#
#      info.toss.decision info.toss.winner  \
# 0                 field      Isle of Man
# 1                 field        Australia
# 2                   bat           Sweden
# 3                   bat     South Africa
# 4                   bat        Hong Kong
# ...                 ...              ...
# 4978                bat        Indonesia
# 4979                bat      Philippines
# 4980              field          Namibia
# 4981              field      Philippines
# 4982                bat         Thailand
#
#                               info.umpires  \
# 0               [S Kuchimanchi, A Paleker]
# 1              [A Paleker, Stephen Harris]
# 2                [DH Mclean, M Prabhudesa]
# 3                 [RJ Bailey, RT Robinson]
# 4     [Aasif Iqbal, Shameem Abdul Basheer]
# ...                                    ...
# 4978                    [F Shony, S Hawoe]
# 4979    [Suresh Subramanian, Tanvir Ahmed]
# 4980              [AT Holdstock, L Rusere]
# 4981          [KK Ghosh, KSVP Venu Madhav]
# 4982         [Samad Akbar, S Jeyasooriyam]
#
#                                              info.venue  match_id    info.city
# 0                        Kerava National Cricket Ground         1       Kerava
# 1                                     Kingsmead, Durban         2       Durban
# 2                            Simar Cricket Ground, Rome         3         Rome
# 3                                         The Rose Bowl         4  Southampton
# 4                           Malek Cricket Ground, Ajman         5        Ajman
# ...                                                 ...       ...          ...
# 4978                             Udayana Cricket Ground      4979         Bali
# 4979                    Yeonhui Cricket Ground, Incheon      4980      Incheon
# 4980  Sir Vivian Richards Stadium, North Sound, Antigua      4981  North Sound
# 4981                  Singapore National Cricket Ground      4982    Singapore
# 4982                   Terdthai Cricket Ground, Bangkok      4983      Bangkok
#
# [4983 rows x 14 columns]

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male      3140
# female    1843
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# /tmp/ipython-input-2142223783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Cyprus', 'deliverie...  [2022-07-12]
# 1     [{'1st innings': {'team': 'South Africa', 'del...  [2023-09-01]
# 3     [{'1st innings': {'team': 'South Africa', 'del...  [2017-06-21]
# 7     [{'1st innings': {'team': 'Pakistan', 'deliver...  [2010-09-07]
# 8     [{'1st innings': {'team': 'Australia', 'delive...  [2011-01-12]
# ...                                                 ...           ...
# 4976  [{'1st innings': {'team': 'South Africa', 'del...  [2021-04-10]
# 4977  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2022-10-13]
# 4978  [{'1st innings': {'team': 'Indonesia', 'delive...  [2025-07-10]
# 4979  [{'1st innings': {'team': 'Philippines', 'deli...  [2024-10-05]
# 4980  [{'1st innings': {'team': 'England', 'deliveri...  [2024-06-15]
#
#      info.match_type info.outcome.winner  info.overs info.player_of_match  \
# 0                T20         Isle of Man          20          [G Burrows]
# 1                T20           Australia          20          [SA Abbott]
# 3                T20             England          20        [JM Bairstow]
# 7                T20             England          20         [TT Bresnan]
# 8                T20             England          20          [SR Watson]
# ...              ...                 ...         ...                  ...
# 4976             T20            Pakistan          20    [Mohammad Rizwan]
# 4977             T20            Pakistan          20    [Mohammad Rizwan]
# 4978             T20         Philippines          20          [KD Kesuma]
# 4979             T20         Philippines          20         [KDA Lukies]
# 4980             T20             England          20           [HC Brook]
#
#                       info.teams info.toss.decision info.toss.winner  \
# 0          [Cyprus, Isle of Man]              field      Isle of Man
# 1      [South Africa, Australia]              field        Australia
# 3        [England, South Africa]                bat     South Africa
# 7            [England, Pakistan]                bat         Pakistan
# 8           [Australia, England]                bat        Australia
# ...                          ...                ...              ...
# 4976    [South Africa, Pakistan]                bat     South Africa
# 4977      [Bangladesh, Pakistan]                bat       Bangladesh
# 4978    [Indonesia, Philippines]                bat        Indonesia
# 4979  [Philippines, South Korea]                bat      Philippines
# 4980          [England, Namibia]              field          Namibia
#
#                             info.umpires  \
# 0             [S Kuchimanchi, A Paleker]
# 1            [A Paleker, Stephen Harris]
# 3               [RJ Bailey, RT Robinson]
# 7             [IJ Gould, RK Illingworth]
# 8                 [SD Fry, BNJ Oxenford]
# ...                                  ...
# 4976           [AT Holdstock, A Paleker]
# 4977               [SB Haig, WR Knights]
# 4978                  [F Shony, S Hawoe]
# 4979  [Suresh Subramanian, Tanvir Ahmed]
# 4980            [AT Holdstock, L Rusere]
#
#                                              info.venue  match_id  \
# 0                        Kerava National Cricket Ground         1
# 1                                     Kingsmead, Durban         2
# 3                                         The Rose Bowl         4
# 7                                        Sophia Gardens         8
# 8                                         Adelaide Oval         9
# ...                                                 ...       ...
# 4976                The Wanderers Stadium, Johannesburg      4977
# 4977                          Hagley Oval, Christchurch      4978
# 4978                             Udayana Cricket Ground      4979
# 4979                    Yeonhui Cricket Ground, Incheon      4980
# 4980  Sir Vivian Richards Stadium, North Sound, Antigua      4981
#
#          info.city
# 0           Kerava
# 1           Durban
# 3      Southampton
# 7          Cardiff
# 8              NaN
# ...            ...
# 4976  Johannesburg
# 4977  Christchurch
# 4978          Bali
# 4979       Incheon
# 4980   North Sound
#
# [3140 rows x 13 columns]

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    3140
# Name: count, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    3132
# 50       8
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# /tmp/ipython-input-3157072726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Cyprus', 'deliverie...  [2022-07-12]
# 1     [{'1st innings': {'team': 'South Africa', 'del...  [2023-09-01]
# 3     [{'1st innings': {'team': 'South Africa', 'del...  [2017-06-21]
# 7     [{'1st innings': {'team': 'Pakistan', 'deliver...  [2010-09-07]
# 8     [{'1st innings': {'team': 'Australia', 'delive...  [2011-01-12]
# ...                                                 ...           ...
# 4976  [{'1st innings': {'team': 'South Africa', 'del...  [2021-04-10]
# 4977  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2022-10-13]
# 4978  [{'1st innings': {'team': 'Indonesia', 'delive...  [2025-07-10]
# 4979  [{'1st innings': {'team': 'Philippines', 'deli...  [2024-10-05]
# 4980  [{'1st innings': {'team': 'England', 'deliveri...  [2024-06-15]
#
#      info.outcome.winner info.player_of_match                  info.teams  \
# 0            Isle of Man          [G Burrows]       [Cyprus, Isle of Man]
# 1              Australia          [SA Abbott]   [South Africa, Australia]
# 3                England        [JM Bairstow]     [England, South Africa]
# 7                England         [TT Bresnan]         [England, Pakistan]
# 8                England          [SR Watson]        [Australia, England]
# ...                  ...                  ...                         ...
# 4976            Pakistan    [Mohammad Rizwan]    [South Africa, Pakistan]
# 4977            Pakistan    [Mohammad Rizwan]      [Bangladesh, Pakistan]
# 4978         Philippines          [KD Kesuma]    [Indonesia, Philippines]
# 4979         Philippines         [KDA Lukies]  [Philippines, South Korea]
# 4980             England           [HC Brook]          [England, Namibia]
#
#      info.toss.decision info.toss.winner                        info.umpires  \
# 0                 field      Isle of Man          [S Kuchimanchi, A Paleker]
# 1                 field        Australia         [A Paleker, Stephen Harris]
# 3                   bat     South Africa            [RJ Bailey, RT Robinson]
# 7                   bat         Pakistan          [IJ Gould, RK Illingworth]
# 8                   bat        Australia              [SD Fry, BNJ Oxenford]
# ...                 ...              ...                                 ...
# 4976                bat     South Africa           [AT Holdstock, A Paleker]
# 4977                bat       Bangladesh               [SB Haig, WR Knights]
# 4978                bat        Indonesia                  [F Shony, S Hawoe]
# 4979                bat      Philippines  [Suresh Subramanian, Tanvir Ahmed]
# 4980              field          Namibia            [AT Holdstock, L Rusere]
#
#                                              info.venue  match_id  \
# 0                        Kerava National Cricket Ground         1
# 1                                     Kingsmead, Durban         2
# 3                                         The Rose Bowl         4
# 7                                        Sophia Gardens         8
# 8                                         Adelaide Oval         9
# ...                                                 ...       ...
# 4976                The Wanderers Stadium, Johannesburg      4977
# 4977                          Hagley Oval, Christchurch      4978
# 4978                             Udayana Cricket Ground      4979
# 4979                    Yeonhui Cricket Ground, Incheon      4980
# 4980  Sir Vivian Richards Stadium, North Sound, Antigua      4981
#
#          info.city
# 0           Kerava
# 1           Durban
# 3      Southampton
# 7          Cardiff
# 8              NaN
# ...            ...
# 4976  Johannesburg
# 4977  Christchurch
# 4978          Bali
# 4979       Incheon
# 4980   North Sound
#
# [3132 rows x 11 columns]

# %%
import pickle

with open("dataset_level1.pkl", "wb") as f:
    pickle.dump(final_df, f)

# %%
with open("dataset_level1.pkl", "rb") as f:
    matches = pickle.load(f)
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'AUKDS Kalugala',
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {0.2: {'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'AUKDS Kalugala',
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {0.3: {'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'non_striker': 'AUKDS Kalugala',
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {0.4: {'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'AUKDS Kalugala',
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {0.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'AUKDS Kalugala'}},
#  {0.6: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'AUKDS Kalugala'}},
#  {1.1: {'non_striker': 'AUKDS Kalugala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {1.2: {'non_striker': 'AUKDS Kalugala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {1.3: {'non_striker': 'AUKDS Kalugala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {1.4: {'non_striker': 'AUKDS Kalugala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {1.5: {'non_striker': 'AUKDS Kalugala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {1.6: {'non_striker': 'AUKDS Kalugala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {1.7: {'non_striker': 'AUKDS Kalugala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {2.1: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'AUKDS Kalugala'}},
#  {2.2: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'AUKDS Kalugala'}},
#  {2.3: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'AUKDS Kalugala'}},
#  {2.4: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'AUKDS Kalugala'}},
#  {2.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'AUKDS Kalugala',
#    'wicket': {'player_out': 'AUKDS Kalugala',
#     'fielders': ['JA Burrows'],
#     'kind': 'caught'}}},
#  {2.6: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {2.7: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {2.8: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {3.1: {'non_striker': 'CPPM Sadun',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {3.2: {'non_striker': 'CPPM Sadun',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {3.3: {'non_striker': 'CPPM Sadun',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {3.4: {'non_striker': 'CPPM Sadun',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {3.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'CPPM Sadun'}},
#  {3.6: {'non_striker': 'CPPM Sadun',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {4.1: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {4.2: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {4.3: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {4.4: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'CPPM Sadun'}},
#  {4.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {4.6: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'CPPM Sadun'}},
#  {5.1: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'CPPM Sadun'}},
#  {5.2: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'CPPM Sadun'}},
#  {5.3: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'J Butler',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'CPPM Sadun'}},
#  {5.4: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'CPPM Sadun'}},
#  {5.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {5.6: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun'}},
#  {5.7: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'CPPM Sadun'}},
#  {6.1: {'non_striker': 'CPPM Sadun',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {6.2: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'CPPM Sadun',
#    'wicket': {'player_out': 'CPPM Sadun',
#     'fielders': ['N Knights'],
#     'kind': 'caught'}}},
#  {6.3: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Gurpratap Singh'}},
#  {6.4: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Gurpratap Singh'}},
#  {6.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Gurpratap Singh'}},
#  {6.6: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Gurpratap Singh'}},
#  {7.1: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Gurpratap Singh'}},
#  {7.2: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Gurpratap Singh'}},
#  {7.3: {'non_striker': 'Gurpratap Singh',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {7.4: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Gurpratap Singh'}},
#  {7.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Gurpratap Singh'}},
#  {7.6: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Gurpratap Singh'}},
#  {8.1: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Gurpratap Singh'}},
#  {8.2: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Gurpratap Singh'}},
#  {8.3: {'non_striker': 'Gurpratap Singh',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {8.4: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'Gurpratap Singh'}},
#  {8.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Gurpratap Singh',
#    'wicket': {'player_out': 'Gurpratap Singh', 'kind': 'bowled'}}},
#  {8.6: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'S Austin'}},
#  {9.1: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'S Austin'}},
#  {9.2: {'non_striker': 'S Austin',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {9.3: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'S Austin'}},
#  {9.4: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'S Austin'}},
#  {9.5: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 3, 'total': 3, 'batsman': 0},
#    'extras': {'wides': 3},
#    'batsman': 'S Austin'}},
#  {9.6: {'non_striker': 'Muhammad Shoaib Ahmed',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'S Austin',
#    'wicket': {'player_out': 'S Austin',
#     'fielders': ['JA Burrows'],
#     'kind': 'caught'}}},
#  {9.7: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {10.1: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {10.2: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed'}},
#  {10.3: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Muhammad Shoaib Ahmed',
#    'wicket': {'player_out': 'Muhammad Shoaib Ahmed',
#     'fielders': ['EF Beard'],
#     'kind': 'caught'}}},
#  {10.4: {'bowler': 'J Butler',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'non_striker': 'NK Tiwari',
#    'batsman': 'R Mazumder'}},
#  {10.5: {'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'NK Tiwari',
#    'batsman': 'R Mazumder'}},
#  {10.6: {'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'NK Tiwari',
#    'batsman': 'R Mazumder'}},
#  {10.7: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {11.1: {'non_striker': 'NK Tiwari',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'R Mazumder'}},
#  {11.2: {'non_striker': 'NK Tiwari',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'R Mazumder'}},
#  {11.3: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {11.4: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {11.5: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'NK Tiwari'}},
#  {11.6: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {11.7: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'NK Tiwari'}},
#  {12.1: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'NK Tiwari'}},
#  {12.2: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'legbyes': 1},
#    'batsman': 'NK Tiwari'}},
#  {12.3: {'non_striker': 'NK Tiwari',
#    'bowler': 'J Butler',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'R Mazumder'}},
#  {12.4: {'non_striker': 'NK Tiwari',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'R Mazumder'}},
#  {12.5: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {12.6: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'batsman': 'NK Tiwari'}},
#  {12.7: {'non_striker': 'R Mazumder',
#    'bowler': 'J Butler',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {13.1: {'non_striker': 'NK Tiwari',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'legbyes': 1},
#    'batsman': 'R Mazumder'}},
#  {13.2: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {13.3: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {13.4: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'NK Tiwari'}},
#  {13.5: {'non_striker': 'NK Tiwari',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'R Mazumder'}},
#  {13.6: {'non_striker': 'R Mazumder',
#    'bowler': 'D Jansen',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'NK Tiwari'}},
#  {14.1: {'non_striker': 'R Mazumder',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari'}},
#  {14.2: {'non_striker': 'R Mazumder',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'NK Tiwari'}},
#  {14.3: {'non_striker': 'NK Tiwari',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'R Mazumder'}},
#  {14.4: {'non_striker': 'R Mazumder',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#    'batsman': 'NK Tiwari'}},
#  {14.5: {'non_striker': 'R Mazumder',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'NK Tiwari'}},
#  {14.6: {'non_striker': 'NK Tiwari',
#    'bowler': 'CJ Langford',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'R Mazumder',
#    'wicket': {'player_out': 'R Mazumder', 'kind': 'bowled'}}},
#  {15.1: {'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'Tejwinder Singh',
#    'batsman': 'NK Tiwari'}},
#  {15.2: {'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'Tejwinder Singh',
#    'batsman': 'NK Tiwari'}},
#  {15.3: {'bowler': 'K Cawte',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'non_striker': 'Tejwinder Singh',
#    'batsman': 'NK Tiwari'}},
#  {15.4: {'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'Tejwinder Singh',
#    'batsman': 'NK Tiwari'}},
#  {15.5: {'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'non_striker': 'Tejwinder Singh',
#    'batsman': 'NK Tiwari'}},
#  {15.6: {'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'Tejwinder Singh',
#    'batsman': 'NK Tiwari'}},
#  {15.7: {'non_striker': 'NK Tiwari',
#    'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Tejwinder Singh',
#    'wicket': {'player_out': 'Tejwinder Singh', 'kind': 'bowled'}}},
#  {16.1: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'NK Tiwari',
#    'wicket': {'player_out': 'NK Tiwari',
#     'fielders': ['G Burrows'],
#     'kind': 'caught'}}},
#  {16.2: {'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'SRMJJ Arachchilage',
#    'batsman': 'SN Pathirana'}},
#  {16.3: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {16.4: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {16.5: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {16.6: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {17.1: {'non_striker': 'SN Pathirana',
#    'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {17.2: {'non_striker': 'SRMJJ Arachchilage',
#    'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SN Pathirana'}},
#  {17.3: {'non_striker': 'SN Pathirana',
#    'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {17.4: {'non_striker': 'SN Pathirana',
#    'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {17.5: {'non_striker': 'SRMJJ Arachchilage',
#    'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SN Pathirana'}},
#  {17.6: {'non_striker': 'SN Pathirana',
#    'bowler': 'K Cawte',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {18.1: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'SRMJJ Arachchilage'}},
#  {18.2: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SRMJJ Arachchilage',
#    'wicket': {'player_out': 'SRMJJ Arachchilage',
#     'fielders': ['J Butler'],
#     'kind': 'caught'}}},
#  {18.3: {'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'Riyaz Kajalwala',
#    'batsman': 'SN Pathirana'}},
#  {18.4: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Riyaz Kajalwala'}},
#  {18.5: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Riyaz Kajalwala'}},
#  {18.6: {'non_striker': 'SN Pathirana',
#    'bowler': 'JA Burrows',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Riyaz Kajalwala'}},
#  {19.1: {'non_striker': 'Riyaz Kajalwala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'batsman': 'SN Pathirana'}},
#  {19.2: {'non_striker': 'Riyaz Kajalwala',
#    'bowler': 'MJ Ansell',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'SN Pathirana',
#    'wicket': {'player_out': 'SN Pathirana',
#     'fielders': ['A McAuley', 'C Hartmann'],
#     'kind': 'run out'}}}]

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    # The problematic match IDs below seem to cause issues due to inconsistent structure.
    # Skipping these specific matches to avoid errors and proceed with the rest of the data.
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue

    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []

    # Accessing the first innings deliveries. Ensure 'innings' is a list of dicts.
    first_innings_data = row['innings'][0]
    deliveries = first_innings_data['1st innings']['deliveries']

    for ball in deliveries:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(first_innings_data['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    # Using pd.concat for efficiency instead of append in loop
    delivery_df = pd.concat([delivery_df, loop_df], ignore_index=True)
    count+=1

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#         match_id                  teams batting_team  ball  \
# 0              1  [Cyprus, Isle of Man]       Cyprus   0.1
# 1              1  [Cyprus, Isle of Man]       Cyprus   0.2
# 2              1  [Cyprus, Isle of Man]       Cyprus   0.3
# 3              1  [Cyprus, Isle of Man]       Cyprus   0.4
# 4              1  [Cyprus, Isle of Man]       Cyprus   0.5
# ...          ...                    ...          ...   ...
# 376869      3132     [England, Namibia]      England   9.2
# 376870      3132     [England, Namibia]      England   9.3
# 376871      3132     [England, Namibia]      England   9.4
# 376872      3132     [England, Namibia]      England   9.5
# 376873      3132     [England, Namibia]      England   9.6
#
#                       batsman         bowler  runs player_dismissed  \
# 0       Muhammad Shoaib Ahmed    CJ Langford     0                0
# 1       Muhammad Shoaib Ahmed    CJ Langford     0                0
# 2       Muhammad Shoaib Ahmed    CJ Langford     4                0
# 3       Muhammad Shoaib Ahmed    CJ Langford     1                0
# 4              AUKDS Kalugala    CJ Langford     0                0
# ...                       ...            ...   ...              ...
# 376869                 MM Ali  R Trumpelmann     0           MM Ali
# 376870         LS Livingstone  R Trumpelmann     6                0
# 376871         LS Livingstone  R Trumpelmann     6                0
# 376872         LS Livingstone  R Trumpelmann     2                0
# 376873         LS Livingstone  R Trumpelmann     1   LS Livingstone
#
#                city                                              venue  \
# 0            Kerava                     Kerava National Cricket Ground
# 1            Kerava                     Kerava National Cricket Ground
# 2            Kerava                     Kerava National Cricket Ground
# 3            Kerava                     Kerava National Cricket Ground
# 4            Kerava                     Kerava National Cricket Ground
# ...             ...                                                ...
# 376869  North Sound  Sir Vivian Richards Stadium, North Sound, Antigua
# 376870  North Sound  Sir Vivian Richards Stadium, North Sound, Antigua
# 376871  North Sound  Sir Vivian Richards Stadium, North Sound, Antigua
# 376872  North Sound  Sir Vivian Richards Stadium, North Sound, Antigua
# 376873  North Sound  Sir Vivian Richards Stadium, North Sound, Antigua
#
#        bowling_team
# 0       Isle of Man
# 1       Isle of Man
# 2       Isle of Man
# 3       Isle of Man
# 4       Isle of Man
# ...             ...
# 376869      Namibia
# 376870      Namibia
# 376871      Namibia
# 376872      Namibia
# 376873      Namibia
#
# [376874 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].value_counts()
# Out:
# batting_team
# Pakistan                   18158
# India                      17887
# New Zealand                16059
# Sri Lanka                  14036
# South Africa               13627
#                            ...
# Ivory Coast                  310
# Chile                        261
# Turks and Caicos Island      254
# China                        218
# Iran                         131
# Name: count, Length: 106, dtype: int64

# %%
top20_teams = delivery_df['batting_team'].value_counts().head(20)

# %%
top20_teams
# Out:
# ['Pakistan',
#  'India',
#  'New Zealand',
#  'Sri Lanka',
#  'South Africa',
#  'West Indies',
#  'England',
#  'Bangladesh',
#  'Zimbabwe',
#  'Australia',
#  'Ireland',
#  'Hong Kong',
#  'Netherlands',
#  'United Arab Emirates',
#  'Malaysia',
#  'Nigeria',
#  'Uganda',
#  'Bahrain',
#  'Scotland',
#  'Nepal']

# %%
teams=['Pakistan',
 'India',
 'New Zealand',
 'Sri Lanka',
 'South Africa',
 'West Indies',
 'England',
 'Bangladesh',
 'Zimbabwe',
 'Australia',
 'Ireland',
 'Hong Kong',
 'Netherlands',
 'United Arab Emirates',
 'Malaysia',
 'Nigeria',
 'Uganda',
 'Bahrain',
 'Scotland',
 'Nepal']

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#         match_id  batting_team  ball             batsman          bowler  \
# 125            2  South Africa   0.1        RR Hendricks       AM Hardie
# 126            2  South Africa   0.2            T Bavuma       AM Hardie
# 127            2  South Africa   0.3            T Bavuma       AM Hardie
# 128            2  South Africa   0.4            T Bavuma       AM Hardie
# 129            2  South Africa   0.5            T Bavuma       AM Hardie
# ...          ...           ...   ...                 ...             ...
# 376563      3129    Bangladesh  19.2         Nurul Hasan  Mohammad Wasim
# 376564      3129    Bangladesh  19.3         Nurul Hasan  Mohammad Wasim
# 376565      3129    Bangladesh  19.4         Nurul Hasan  Mohammad Wasim
# 376566      3129    Bangladesh  19.5  Mohammad Saifuddin  Mohammad Wasim
# 376567      3129    Bangladesh  19.6         Nurul Hasan  Mohammad Wasim
#
#         runs player_dismissed          city                      venue  \
# 125        1                0        Durban          Kingsmead, Durban
# 126        4                0        Durban          Kingsmead, Durban
# 127        0                0        Durban          Kingsmead, Durban
# 128        0                0        Durban          Kingsmead, Durban
# 129        4                0        Durban          Kingsmead, Durban
# ...      ...              ...           ...                        ...
# 376563     0                0  Christchurch  Hagley Oval, Christchurch
# 376564     0                0  Christchurch  Hagley Oval, Christchurch
# 376565     0     Afif Hossain  Christchurch  Hagley Oval, Christchurch
# 376566     1                0  Christchurch  Hagley Oval, Christchurch
# 376567     2                0  Christchurch  Hagley Oval, Christchurch
#
#        bowling_team
# 125       Australia
# 126       Australia
# 127       Australia
# 128       Australia
# 129       Australia
# ...             ...
# 376563     Pakistan
# 376564     Pakistan
# 376565     Pakistan
# 376566     Pakistan
# 376567     Pakistan
#
# [164054 rows x 10 columns]

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#         match_id  batting_team bowling_team  ball  runs player_dismissed  \
# 125            2  South Africa    Australia   0.1     1                0
# 126            2  South Africa    Australia   0.2     4                0
# 127            2  South Africa    Australia   0.3     0                0
# 128            2  South Africa    Australia   0.4     0                0
# 129            2  South Africa    Australia   0.5     4                0
# ...          ...           ...          ...   ...   ...              ...
# 376563      3129    Bangladesh     Pakistan  19.2     0                0
# 376564      3129    Bangladesh     Pakistan  19.3     0                0
# 376565      3129    Bangladesh     Pakistan  19.4     0     Afif Hossain
# 376566      3129    Bangladesh     Pakistan  19.5     1                0
# 376567      3129    Bangladesh     Pakistan  19.6     2                0
#
#                 city                      venue
# 125           Durban          Kingsmead, Durban
# 126           Durban          Kingsmead, Durban
# 127           Durban          Kingsmead, Durban
# 128           Durban          Kingsmead, Durban
# 129           Durban          Kingsmead, Durban
# ...              ...                        ...
# 376563  Christchurch  Hagley Oval, Christchurch
# 376564  Christchurch  Hagley Oval, Christchurch
# 376565  Christchurch  Hagley Oval, Christchurch
# 376566  Christchurch  Hagley Oval, Christchurch
# 376567  Christchurch  Hagley Oval, Christchurch
#
# [164054 rows x 8 columns]

# %%
import pickle

with open("dataset_level2.pkl", "wb") as f:
    pickle.dump(output, f)

# %%
teams
# Out:
# ['Pakistan',
#  'India',
#  'New Zealand',
#  'Sri Lanka',
#  'South Africa',
#  'West Indies',
#  'England',
#  'Bangladesh',
#  'Zimbabwe',
#  'Australia',
#  'Ireland',
#  'Hong Kong',
#  'Netherlands',
#  'United Arab Emirates',
#  'Malaysia',
#  'Nigeria',
#  'Uganda',
#  'Bahrain',
#  'Scotland',
#  'Nepal']

# %%
import pandas as pd
pd.Series(city).unique()
# Out:
# array(['North Sound'], dtype=object)

# %% [markdown]
# To access files in your Google Drive, you first need to mount your Drive to this Colab environment. This will allow you to navigate your Drive folders and files.

# %% [markdown]
# After executing the above cell and following the authentication steps, your Google Drive will be mounted at `/content/drive`. You can then list the contents of your Drive using shell commands like `!ls /content/drive/MyDrive`.
